# %%
print("Hello, Data Science!")
print("Welcome to Chapter 01 – Python Basics")
# Out:
# Hello, Data Science!
# Welcome to Chapter 01 – Python Basics

# %%
x = 10
y = 20
print("Sum: ", x + y)
# Out:
# Sum:  30

# %%
# Input function
name = input("What is your name: ")
print("Hello,",name,"!")
# Out:
# Hello, Tanmoy !
